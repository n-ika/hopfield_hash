# %%
# Uncomment for development/debugging
# %matplotlib inline
import matplotlib.pyplot as plt

# Uncomment to plot nice-looking final figures
"""
import matplotlib as mpl

mpl.style.use('classic')
mpl.use("pgf")
pgf_with_custom_preamble = {
    "font.family": "serif", # use serif/main font for text elements
    "text.usetex": True,    # use inline math for ticks
    "pgf.rcfonts": False,   # don't setup fonts from rc parameters
    "pgf.preamble": [
         "\\usepackage{unicode-math}",  # unicode math setup
         "\\setmainfont{Doulos SIL}" # serif font via preamble
         ]
}
mpl.rcParams.update(pgf_with_custom_preamble)
"""

import numpy as np
import pandas as pd
import seaborn as sns

# %%
fname = './output/data_100N.csv'
df100 = pd.read_csv(fname)
# del df['Unnamed: 0']
df100.type = df100['type'].map({'known':'orig', 'new':'noisy'})

# %%
fname = './output/data_200N.csv'
df200 = pd.read_csv(fname)
# del df['Unnamed: 0']
df200.type = df200['type'].map({'known':'orig', 'new':'noisy'})

# %%
fname = './output/data_500N.csv'
df500 = pd.read_csv(fname)
# del df['Unnamed: 0']
df500.type = df500['type'].map({'known':'orig', 'new':'noisy'})

# %%
np.sort(df500.d.unique())
# Out:
# array([0.01, 0.05, 0.1 , 0.5 , 1.  ])

# %%
pd.set_option('display.max_rows', None)
df100.groupby(by=["d","p","n","U","g"], as_index=False).size()
# Out:
# d     p     n    U      g
# 0.01  0.05  16   0.0    0         64
#             256  0.0    0       1024
#       0.10  15   0.0    0         60
#                         1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.0    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.1    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.9    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  4.0    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  4.1    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  4.9    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  5.0    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  16.0   1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  32.0   1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  64.0   1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  128.0  1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#             16   0.0    0         64
#                         1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  3.0    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  3.1    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  3.9    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  4.0    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  4.1    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  4.9    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  5.0    1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  16.0   1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  32.0   1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  64.0   1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#                  128.0  1         64
#                         2         64
#                         4         64
#                         16        64
#                         32        64
#                         64        64
#                         128       64
#                         256       64
#                         512       64
#                         1024      64
#                         8192      64
#             32   0.0    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.0    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.1    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.9    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.0    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.1    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.9    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  5.0    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  16.0   0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  32.0   0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  64.0   0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  128.0  0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#             64   0.0    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.0    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.1    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.9    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.0    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.1    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.9    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  5.0    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  16.0   0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  32.0   0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  64.0   0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  128.0  0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#             128  0.0    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.0    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.1    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.9    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.0    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.1    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.9    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  5.0    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  16.0   0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  32.0   0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  64.0   0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  128.0  0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
# 0.05  0.05  16   0.0    0         64
#             32   0.0    0        128
#                         1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.0    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.1    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  3.9    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.0    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.1    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  4.9    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  5.0    1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  16.0   1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  32.0   1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  64.0   1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#                  128.0  1        128
#                         2        128
#                         4        128
#                         16       128
#                         32       128
#                         64       128
#                         128      128
#                         256      128
#                         512      128
#                         1024     128
#                         8192     128
#             64   0.0    0        256
#                         1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.0    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.1    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  3.9    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.0    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.1    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  4.9    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  5.0    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  16.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  32.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  64.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  128.0  1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#             128  0.0    0        512
#                         1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  5.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  16.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  32.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  64.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  128.0  1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#             256  0.0    0       1024
#             512  0.0    0       2048
#                         1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  3.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  3.1    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  3.9    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.1    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.9    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  5.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  16.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  32.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  64.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  128.0  1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#       0.10  15   0.0    0         60
#                         1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.0    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.1    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  3.9    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  4.0    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
#                         128       60
#                         256       60
#                         512       60
#                         1024      60
#                         8192      60
#                  4.1    1         60
#                         2         60
#                         4         60
#                         16        60
#                         32        60
#                         64        60
# ...
#                         512      256
#                         1024     256
#                         8192     256
#                  4.9    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  5.0    1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  16.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  32.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  64.0   1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#                  128.0  1        256
#                         2        256
#                         4        256
#                         16       256
#                         32       256
#                         64       256
#                         128      256
#                         256      256
#                         512      256
#                         1024     256
#                         8192     256
#             128  3.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  5.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  16.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  32.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  64.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  128.0  1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#             256  3.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  3.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.1    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  4.9    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  5.0    1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  16.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  32.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  64.0   1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#                  128.0  1        512
#                         2        512
#                         4        512
#                         16       512
#                         32       512
#                         64       512
#                         128      512
#                         256      512
#                         512      512
#                         1024     512
#                         8192     512
#             512  3.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  3.1    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  3.9    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.1    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  4.9    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  5.0    1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  16.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  32.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  64.0   1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
#                  128.0  1       2048
#                         2       2048
#                         4       2048
#                         16      2048
#                         32      2048
#                         64      2048
#                         128     2048
#                         256     2048
#                         512     2048
#                         1024    2048
#                         8192    2048
# dtype: int64

# %%
nd = []
for row in df100[(df100.p==0.05)].itertuples():
    nd.append((row.n, row.d))
set(nd)
# Out:
# {(16, 0.01),
#  (16, 0.05),
#  (16, 0.1),
#  (16, 0.5),
#  (16, 1.0),
#  (32, 0.05),
#  (32, 0.1),
#  (32, 0.5),
#  (32, 1.0),
#  (64, 0.05),
#  (64, 0.1),
#  (64, 0.5),
#  (64, 1.0),
#  (128, 0.05),
#  (128, 0.1),
#  (128, 0.5),
#  (128, 1.0),
#  (256, 0.01),
#  (256, 0.05),
#  (256, 0.1),
#  (256, 0.5),
#  (256, 1.0),
#  (512, 0.05),
#  (512, 0.1),
#  (512, 0.5),
#  (512, 1.0)}

# %%
N500_p005 = nd.copy()

# %%
set(N500_p005)

# %%
set(N500_p01)

# %%
set(N500_p02)

# %%
set(N200_p02)
# Out:
# {(32, 0.01),
#  (32, 0.05),
#  (32, 0.5),
#  (32, 1.0),
#  (64, 0.01),
#  (64, 0.05),
#  (64, 0.5),
#  (64, 1.0),
#  (128, 0.01),
#  (128, 0.05),
#  (128, 0.5),
#  (128, 1.0),
#  (256, 0.01),
#  (256, 0.05),
#  (256, 0.5),
#  (256, 1.0),
#  (512, 0.01),
#  (512, 0.05),
#  (512, 0.5),
#  (512, 1.0)}

# %%
set(N200_p005)
# Out:
# {(16, 0.01),
#  (16, 0.05),
#  (16, 0.5),
#  (16, 1.0),
#  (32, 0.01),
#  (32, 0.05),
#  (32, 0.5),
#  (32, 1.0),
#  (64, 0.01),
#  (64, 0.05),
#  (64, 0.5),
#  (64, 1.0),
#  (128, 0.01),
#  (128, 0.05),
#  (128, 0.5),
#  (128, 1.0),
#  (256, 0.01),
#  (256, 0.05),
#  (256, 0.5),
#  (256, 1.0),
#  (512, 0.01),
#  (512, 0.05),
#  (512, 0.5),
#  (512, 1.0)}

# %%
set(N200_p01)
# Out:
# {(32, 0.01),
#  (32, 0.05),
#  (32, 0.5),
#  (32, 1.0),
#  (64, 0.01),
#  (64, 0.05),
#  (64, 0.5),
#  (64, 1.0),
#  (128, 0.01),
#  (128, 0.05),
#  (128, 0.5),
#  (128, 1.0),
#  (256, 0.01),
#  (256, 0.05),
#  (256, 0.5),
#  (256, 1.0),
#  (512, 0.01),
#  (512, 0.05),
#  (512, 0.5),
#  (512, 1.0)}

# %%
set(N100_p02)

# %%
set(N100_p05)
# Out:
# {(16, 0.01),
#  (16, 0.05),
#  (16, 0.5),
#  (16, 1.0),
#  (32, 0.05),
#  (32, 0.5),
#  (32, 1.0),
#  (64, 0.05),
#  (64, 0.5),
#  (64, 1.0),
#  (128, 0.05),
#  (128, 0.5),
#  (128, 1.0),
#  (256, 0.5),
#  (512, 0.5)}

# %%
set(N100_p01)
# Out:
# {(15, 0.01),
#  (15, 0.05),
#  (15, 0.1),
#  (15, 0.5),
#  (15, 0.75),
#  (15, 1.0),
#  (16, 0.01),
#  (16, 0.05),
#  (16, 0.1),
#  (16, 0.5),
#  (16, 0.75),
#  (16, 1.0),
#  (32, 0.01),
#  (32, 0.05),
#  (32, 0.1),
#  (32, 0.5),
#  (32, 0.75),
#  (32, 1.0),
#  (64, 0.01),
#  (64, 0.05),
#  (64, 0.1),
#  (64, 0.5),
#  (64, 0.75),
#  (64, 1.0),
#  (128, 0.01),
#  (128, 0.05),
#  (128, 0.1),
#  (128, 0.5),
#  (128, 0.75),
#  (128, 1.0),
#  (256, 0.5),
#  (512, 0.5)}

# %% [markdown]
# # ARTIFICIAL Vectors corrupted by d% change - ERROR NUM

# %% [markdown]
# ## N=100, p=[0.05, 0.1, 0.2], d=[0.01, 0.05, 0.5,  0.75, 1]

# %%
p_fixed = 0.1
N_fixed = 100
d_fixed = 0.5

df100_ = df100[(df100.type == "noisy") & (df100.n > 15)]

g = sns.relplot(x='U', y='errors', hue='g', col='n', row='d', data=df100_, kind='line', facet_kws={'sharey': False, 'sharex': False}, ci=None, palette="tab10")
N = set(df100_.N)
n = set(df100_.n)
d = set(df100_.d)
N = np.sort(list(N))
n = np.sort(list(n))
d = np.sort(list(d))

for i in range(len(d)):
    for j in range(len(n)):
        
        g.axes[i,j].set_xscale('log')
        g.axes[i,j].axhline(N_fixed*p_fixed, ls='--', linewidth=3, color='red') #max error if 10% active vals are displaced
        g.axes[i,j].axhline(0, ls='--', linewidth=3, color='green') #0 error
        g.axes[i,j].axhline(d[i]*N_fixed, ls='--', linewidth=3, color='orange') #d

# print all couples u&g with lowest error, print all others not too far

# %% [markdown]
# ## N=200, p=[0.05, 0.1, 0.2], d=[0.01, 0.05, 0.5, 1]

# %%
p_fixed = 0.1
N_fixed = 200
d_fixed = 0.5

# df_n = df[(df.type == "noisy") & (df.p == p_fixed) & (df.N == N_fixed) & (df.d == d_fixed)]

df200_ = df200[(df200.type == "noisy")]

g = sns.relplot(x='U', y='errors', hue='g', col='n', row='d', data=df200_, kind='line', facet_kws={'sharey': False, 'sharex': False}, ci=None, palette="tab10")
N = set(df200_.N)
n = set(df200_.n)
d = set(df200_.d)
N = np.sort(list(N))
n = np.sort(list(n))
d = np.sort(list(d))

for i in range(len(d)):
    for j in range(len(n)):
        
        g.axes[i,j].set_xscale('log')
        g.axes[i,j].axhline(N_fixed*p_fixed, ls='--', linewidth=3, color='red') #max error if 10% active vals are displaced
        g.axes[i,j].axhline(0, ls='--', linewidth=3, color='green') #0 error
        g.axes[i,j].axhline(d[i]*N_fixed, ls='--', linewidth=3, color='orange') #d

# print all couples u&g with lowest error, print all others not too far

# %% [markdown]
# ## N=500, p=[0.05, 0.1, 0.2], d=[0.01, 0.05, 0.5, 1]

# %%
p_fixed = 0.05
N_fixed = 500
d_fixed = 0.5

# df_n = df[(df.type == "noisy") & (df.p == p_fixed) & (df.N == N_fixed) & (df.d == d_fixed)]

df500_ = df500[(df500.type == "noisy")]

g = sns.relplot(x='U', y='errors', hue='g', col='n', row='d', data=df500_, kind='line', facet_kws={'sharey': False, 'sharex': False}, ci=None, palette="tab10")
N = set(df500_.N)
n = set(df500_.n)
d = set(df500_.d)
N = np.sort(list(N))
n = np.sort(list(n))
d = np.sort(list(d))

for i in range(len(d)):
    for j in range(len(n)):
        
        g.axes[i,j].set_xscale('log')
        g.axes[i,j].axhline(N_fixed*p_fixed, ls='--', linewidth=3, color='red') #max error if 10% active vals are displaced
        g.axes[i,j].axhline(0, ls='--', linewidth=3, color='green') #0 error
        g.axes[i,j].axhline(d[i]*N_fixed, ls='--', linewidth=3, color='orange') #d

# print all couples u&g with lowest error, print all others not too far

# %% [markdown]
# ## =============================

# %% [markdown]
# ## WITH DELTA ERROR

# %%
def filter_avg(df_n):
#     df_n = df_n[(df_n.n > 16) & (df_n.n < 256)]
#     df_n = df_n[(df_n.d == 0.05) | (df_n.d == 1)]
#     df_n = df_n[df_n.U > 0]
#     df_n = df_n[df_n.g > 0]
    df_n = df_n.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
    return(df_n)

# %%
def eval_Ug(df_n, N, p, n, d, delta = 1):

    res = {}
    totals = 0
    U = np.sort(df_n.U.unique())
    g = np.sort(df_n.g.unique())
    
    for i in range(len(N)):
        for l in range(len(p)):
            for j in range(len(n)):
                for k in range(len(d)):
                    df_ijkl = df_n[(df_n.N == N[i]) & (df_n.n == n[j]) & (df_n.d == d[k]) & (df_n.p == p[l])]
#                     assert len(df_ijkl) == len(U)*len(g), (df_ijkl, N[i], n[j], d[k], p[l])
                    if not df_ijkl.empty:

                        ind = np.argmin(df_ijkl['errors'])
                        err = df_ijkl.iloc[ind]['errors']
                        df_filt = df_ijkl[(df_ijkl.errors < err + delta)]
                        if err < min(0.9*N[i]*p[l], N[i]*d[k]):
                            totals += 1

                            for row in df_filt.itertuples():
                                if (row.U,row.g) not in res:
                                    res[row.U,row.g] = 1
                                else:
                                    res[row.U,row.g] = res[row.U,row.g] + 1 


    return(res,totals)

# %%
def count_Ug(res, totals, df_n):
    fin = {"U":[],"g":[],"num":[]}
    U_list = np.sort(df_n.U.unique())
    g_list = np.sort(df_n.g.unique())

    for key in res:
        fin["U"].append(key[0])
        fin["g"].append(key[1])
        fin["num"].append(res[key])


    for U in U_list:
        for g in g_list:
    #         print(U,g)
            if not((U,g) in res):
                fin["U"].append(U)
                fin["g"].append(g)
                fin["num"].append(0)

    res_df = pd.DataFrame(fin)
    res_df["total"] = totals
    res_df["prop"] = res_df.num / totals

    return(res_df)

# %%
# def do_stat(df_n, N, p, n, d, delta=1):

#     res = {}
#     totals = {}

#     for i in range(len(N)):
#         for l in range(len(p)):
#             res[N[i],p[l]] = {}
#             totals[N[i],p[l]] = 0
#             for j in range(len(n)):
#                 for k in range(len(d)):
#                     df_ijkl = df_n[(df_n.N == N[i]) & (df_n.n == n[j]) & (df_n.d == d[k]) & (df_n.p == p[l])]
#                     assert len(df_ijkl) == len(U)*len(g), (df_ijkl, N[i], n[j], d[k], p[l])
#     #                 if not df_ijkl.empty:
#                     ind = np.argmin(df_ijkl['errors'])
#                     err = df_ijkl.iloc[ind]['errors']
#                     df_filt = df_ijkl[(df_ijkl.errors < err + delta)]
#                     if err < min(0.9*N[i]*p[l], N[i]*d[k]):
#                         totals[N[i],p[l]] = totals[N[i],p[l]] + 1

#                         for row in df_filt.itertuples():
#                             if (row.U,row.g) not in res[row.N,row.p]:
#                                 res[row.N,row.p][row.U,row.g] = 1
#                             else:
#                                 res[row.N,row.p][row.U,row.g] = res[row.N,row.p][row.U,row.g] + 1 


#     return(res,totals)

# %%
df_n = df200[(df200.type == "noisy") & ((df200.p == 0.05) | (df200.p == 0.1) | (df200.p == 0.2))]
# df_n = df_n[(df_n.n > 16) & (df_n.n < 256)]
# df_n = df_n[(df_n.d == 0.05) | (df_n.d == 1)]
# df_n = df_n[df_n.U > 0]
# df_n = df_n[df_n.g > 0]


N = set(df_n.N)
n = set(df_n.n)
d = set(df_n.d)
p = set(df_n.p)
U = set(df_n.U)
g = set(df_n.g)
N = np.sort(list(N))
n = np.sort(list(n))
d = np.sort(list(d))
p = np.sort(list(p))

df_n = df_n.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()

# %%
df_100_ = df100[(df100.type == "noisy") & ((df100.p == 0.05) | (df100.p == 0.1) | (df100.p == 0.2))]

df_200_ = df200[(df200.type == "noisy") & ((df200.p == 0.05) | (df200.p == 0.1) | (df200.p == 0.2))]

df_500_ = df500[(df500.type == "noisy") & ((df500.p == 0.05) | (df500.p == 0.1) | (df500.p == 0.2))]

# %%
df100avg = df_100_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
df200avg = df_200_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
df500avg = df_500_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()

# %%
N100=filter_avg(df_100_)
N200=filter_avg(df_200_)
N500=filter_avg(df_500_)

# %%
df100avg
# Out:
#          N    n     d     p      U     g     errors
# 0      100   16  0.01  0.05    0.0     0  16.000000
# 1      100   16  0.01  0.05    0.0     1  15.250000
# 2      100   16  0.01  0.05    0.0     2  14.500000
# 3      100   16  0.01  0.05    0.0     4  13.062500
# 4      100   16  0.01  0.05    0.0    16   7.125000
# ...    ...  ...   ...   ...    ...   ...        ...
# 12955  100  512  1.00  0.20  128.0   128  20.000000
# 12956  100  512  1.00  0.20  128.0   256  20.000000
# 12957  100  512  1.00  0.20  128.0   512  20.000000
# 12958  100  512  1.00  0.20  128.0  1024  26.548828
# 12959  100  512  1.00  0.20  128.0  8192  34.005859
#
# [12960 rows x 7 columns]

# %%
df_all = pd.concat([df_100_,df_200_,df_500_])

# %%
p05 = filter_avg(df_all[df_all.p==0.05])
p1 = filter_avg(df_all[df_all.p==0.1])
p2 = filter_avg(df_all[df_all.p==0.2])

# %%
# d = [0.05, 1]
# n = [32, 64, 128]
# p = [0.05, 0.1, 0.2]

# %%
# modify code to show p&N in one graph

# %%
resN100, totalsN100 = eval_Ug(N100, [100], p,n,d)
resN200, totalsN200 = eval_Ug(N200, [200], p,n,d)
resN500, totalsN500 = eval_Ug(N500, [500], p,n,d)

# %%
resp05, totalsp05 = eval_Ug(p05, [100,200,500], [0.05],n,d)
resp1, totalsp1 = eval_Ug(p1, [100,200,500], [0.1],n,d)
resp2, totalsp2 = eval_Ug(p2, [100,200,500], [0.2],n,d)

# %%
N100_Ug = count_Ug(resN100, totalsN100, N100)
N200_Ug = count_Ug(resN200, totalsN200, N200)
N500_Ug = count_Ug(resN500, totalsN500, N500)

# %%
ind = np.argmax(N100_Ug.prop)
top_choice = N100_Ug.iloc[ind].prop
df_filt100 = N100_Ug[N100_Ug.prop > 0.95*top_choice]

ind = np.argmax(N200_Ug.prop)
top_choice = N200_Ug.iloc[ind].prop
df_filt200 = N200_Ug[N200_Ug.prop > 0.95*top_choice]

ind = np.argmax(N500_Ug.prop)
top_choice = N500_Ug.iloc[ind].prop
df_filt500 = N500_Ug[N500_Ug.prop > 0.95*top_choice]

df_topUg = pd.concat([df_filt100, df_filt200, df_filt500])

dfN1 = df_topUg.N.copy().reset_index()
dfN2 = df_topUg.N.copy().reset_index()

dfN1["param"] = np.array(df_topUg.U)
dfN1["param_name"] = "U"

dfN2["param"] = np.array(df_topUg.g)
dfN2["param_name"] = "g"

top = pd.concat([dfN1,dfN2])

top
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-28af76e78c72> in <module>
#      13 df_topUg = pd.concat([df_filt100, df_filt200, df_filt500])
#      14
# ---> 15 dfN1 = df_topUg.N.copy().reset_index()
#      16 dfN2 = df_topUg.N.copy().reset_index()
#      17
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'N'

# %%
df100avg = df_100_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
df200avg = df_200_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
df500avg = df_500_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     411         try:
# --> 412             func = self._get_cython_function(kind, how, values, is_numeric)
#     413         except NotImplementedError:
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_cython_function(self, kind, how, values, is_numeric)
#     385         if func is None:
# --> 386             raise NotImplementedError(
#     387                 f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->int64]
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-9bc6140e8fb2> in <module>
#       1 df100avg = df_100_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
# ----> 2 df200avg = df_200_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
#       3 df500avg = df_500_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1222         """
#    1223         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
# -> 1224         return self._cython_agg_general(
#    1225             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1226         )
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     991         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#     992     ) -> DataFrame:
# --> 993         agg_blocks, agg_items = self._cython_agg_blocks(
#     994             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#     995         )
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1020             locs = block.mgr_locs.as_array
#    1021             try:
# -> 1022                 result, _ = self.grouper.aggregate(
#    1023                     block.values, how, axis=1, min_count=min_count
#    1024                 )
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/ops.py in aggregate(self, values, how, axis, min_count)
#     584         self, values, how: str, axis: int = 0, min_count: int = -1
#     585     ) -> Tuple[np.ndarray, Optional[List[str]]]:
# --> 586         return self._cython_operation(
#     587             "aggregate", values, how, axis, min_count=min_count
#     588         )
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     510             out_shape = (self.ngroups,) + values.shape[1:]
#     511
# --> 512         func, values = self._get_cython_func_and_vals(kind, how, values, is_numeric)
#     513
#     514         if how == "rank":
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_cython_func_and_vals(self, kind, how, values, is_numeric)
#     414             if is_numeric:
#     415                 try:
# --> 416                     values = ensure_float64(values)
#     417                 except TypeError:
#     418                     if lib.infer_dtype(values, skipna=False) == "complex":
#
# KeyboardInterrupt:

# %%
list100 = []
for row in df_filt100.itertuples():
    filtUg = df100avg[(df100avg.g==row.g) & (df100avg.U==row.U)]
    list100.append(filtUg)

Ug_err100 = pd.concat(list100).groupby(by=["N", "d", "p", "n"], as_index=False)["errors"].mean()

list200 = []
for row in df_filt200.itertuples():
    filtUg = df200avg[(df200avg.g==row.g) & (df200avg.U==row.U)]
    list200.append(filtUg)

Ug_err200 = pd.concat(list200).groupby(by=["N", "d", "p", "n"], as_index=False)["errors"].mean()


list500 = []
for row in df_filt500.itertuples():
    filtUg = df500avg[(df500avg.g==row.g) & (df500avg.U==row.U)]
    list500.append(filtUg)

Ug_err500 = pd.concat(list500).groupby(by=["N", "d", "p", "n"], as_index=False)["errors"].mean()

Ug_err = pd.concat([Ug_err100, Ug_err200, Ug_err500])

# %%
g = sns.relplot(x='n', y='errors', col='N', row="p", hue = "d", data=Ug_err, kind='line', legend="full", palette="tab20", facet_kws={'sharey': True})

# %%
g = sns.relplot(x='n', y='errors', col='N', row="d", data=Ug_err, kind='scatter', legend="full", palette="tab20", facet_kws={'sharey': False})
# add an axe for p - 3d graph
g.axes[0,0].set_yscale('log')

# test with N=300,400

# %%
p05_Ug = count_Ug(resp05, totalsp05, p05)
p1_Ug = count_Ug(resp1, totalsp1, p1)
p2_Ug = count_Ug(resp2, totalsp2, p2)

# %%
N100_Ug["N"] = 100
N200_Ug["N"] = 200
N500_Ug["N"] = 500

p05_Ug["p"] = 0.05
p1_Ug["p"] = 0.1
p2_Ug["p"] = 0.2

# %%
df_N = pd.concat([N100_Ug,N200_Ug,N500_Ug])
df_p = pd.concat([p05_Ug, p1_Ug, p2_Ug])

# %%
g = sns.relplot(x='g', y='prop', hue='U', data=df_N, col="N", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])

g.axes[0,0].set_xscale('log')

# %%
g = sns.relplot(x='N', y='U', hue='g', data=df_N, col="N", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g

# %%
g = sns.relplot(x='U', y='prop', hue='g', data=df_N, col="N", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g

# %%
g = sns.relplot(x='U', y='num', hue='g', data=df_N, col="N", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g

# %%
g = sns.relplot(x='U', y='prop', hue='g', data=df_p, col="p", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g

# %%
g = sns.relplot(x='U', y='num', hue='g', data=df_p, col="p", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g

# %%
g = sns.relplot(x='U', y='num', hue='g', data=df_p, col="N", row="p", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
g
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-df410892605d> in <module>
# ----> 1 g = sns.relplot(x='U', y='num', hue='g', data=df_p, col="N", row="p", kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])
#       2 g
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/seaborn/relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#     989     grid_semantics = "row", "col"
#     990     p.semantics = plot_semantics + grid_semantics
# --> 991     p.assign_variables(
#     992         data=data,
#     993         variables=dict(
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     665         else:
#     666             self.input_format = "long"
# --> 667             plot_data, variables = self._assign_variables_longform(
#     668                 data, **variables,
#     669             )
#
# ~/miniconda/envs/shennong/lib/python3.8/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     885                     # We don't know what this name means
#     886                     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 887                     raise ValueError(err)
#     888
#     889             else:
#
# ValueError: Could not interpret value `N` for parameter `col`

# %% [markdown]
# ---
#
# Various tests
# ---

# %%
df_n.groupby(by=["n","d","p"], as_index=False).size()
# Out:
# n    d     p
# 15   0.01  0.10    133
#      0.05  0.10    133
#      0.10  0.10    133
#      0.50  0.10    133
#      0.75  0.10    133
#      1.00  0.10    133
# 16   0.01  0.05      1
#            0.10    133
#      0.05  0.05      1
#            0.10    133
#      0.10  0.05      1
#            0.10    133
#      0.50  0.05      1
#            0.10    133
#      0.75  0.10    133
#      1.00  0.05      1
#            0.10    133
# 32   0.01  0.10    144
#      0.05  0.05    133
#            0.10    144
#            0.20    121
#      0.10  0.05      1
#            0.10    144
#      0.50  0.05    133
#            0.10    144
#            0.20    121
#      0.75  0.10    144
#      1.00  0.05    133
#            0.10    144
#            0.20    121
# 64   0.01  0.10    144
#      0.05  0.05    133
#            0.10    144
#            0.20    121
#      0.10  0.05      1
#            0.10    144
#      0.50  0.05    133
#            0.10    144
#            0.20    121
#      0.75  0.10    144
#      1.00  0.05    133
#            0.10    144
#            0.20    121
# 128  0.01  0.10    144
#      0.05  0.05    133
#            0.10    144
#            0.20    121
#      0.10  0.05      1
#            0.10    144
#      0.50  0.05    133
#            0.10    144
#            0.20    121
#      0.75  0.10    144
#      1.00  0.05    133
#            0.10    144
#            0.20    121
# 256  0.01  0.05      1
#      0.05  0.05      1
#      0.10  0.05      1
#      0.50  0.05    133
#            0.10    121
#            0.20    121
#      1.00  0.05      1
# 512  0.05  0.05    133
#            0.10    121
#            0.20    121
#      0.10  0.05      1
#      0.50  0.05    133
#            0.10    121
#            0.20    121
#      1.00  0.05    133
#            0.10    121
#            0.20    121
# dtype: int64

# %%
df500_ = df500[df500.type =="noisy"]
df500_ = df500_.groupby(by=["N","n","d","p","U","g"], as_index=False)["errors"].mean()
len(df500_)
# Out:
# 7539

# %%
totalsp05
# Out:
# 7

# %%
pd.set_option('display.max_rows', None)
df_n.groupby(by=["U","g"], as_index=False).size()
# Out:
# U      g
# 0.0    0        87
#        1        76
#        2        76
#        4        76
#        16       76
#        32       76
#        64       76
#        128      76
#        256      76
#        512      76
#        1024     76
#        8192     76
# 3.0    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 3.1    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 3.9    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 4.0    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 4.1    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 4.9    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 5.0    0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 16.0   0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 32.0   0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 64.0   0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# 128.0  0        18
#        1       159
#        2       159
#        4       159
#        16      159
#        32      159
#        64      159
#        128     159
#        256     159
#        512     159
#        1024    159
#        8192    159
# dtype: int64

# %%
g_list
# Out:
# array([   1,    2,    4,   16,   32,   64,  128,  256,  512, 1024, 8192])

# %%
U_list
# Out:
# array([  3. ,   3.1,   3.9,   4. ,   4.1,   4.9,   5. ,  16. ,  32. ,
#         64. , 128. ])

# %%
g = sns.relplot(x='U', y='num', hue='g', data=res_df, kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])

# %%
g = sns.relplot(x='g', y='num', hue='U', data=res_df, kind='line', legend="full", palette="tab20", markers=['o', 'x', '^', '+', '*', '8', 's', 'p', 'D', 'V'])

# %%
df_filt = df_n[(df_n.U==16) & (df_n.g==1024) & (df_n.d==0.05)]

g = sns.relplot(x='N', y='errors', hue='p', col="d", row="n", data=df_filt, kind='line', legend="full", palette="rainbow")

# %%
gg = np.sort(res_df.g.unique())
list(gg)
# Out:
# [1, 2, 4, 16, 32, 64, 128, 256, 512, 1024, 8192]
